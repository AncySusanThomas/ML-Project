# %% [markdown]
# # US Regional Sales Data

# %% [markdown]
# We are Sorting these things
# <li>.Time Series Analysis</li>
# <li>.Sales Channel Comparison</li>
# <li>.Product Analysis</li>
# <li>.Discount Analysis</li>
# <li>.Regional Performance</li>

# %%
import pandas as pd
import matplotlib .pyplot as plt 
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\MICRO\Documents\anzz\US_Regional_Sales_Data.csv")

# %%
df
# Out:
#        OrderNumber Sales Channel WarehouseCode ProcuredDate OrderDate  \
# 0      SO - 000101      In-Store  WARE-UHY1004     31/12/17   31/5/18
# 1      SO - 000102        Online  WARE-NMK1003     31/12/17   31/5/18
# 2      SO - 000103   Distributor  WARE-UHY1004     31/12/17   31/5/18
# 3      SO - 000104     Wholesale  WARE-NMK1003     31/12/17   31/5/18
# 4      SO - 000105   Distributor  WARE-NMK1003      10/4/18   31/5/18
# ...            ...           ...           ...          ...       ...
# 7986  SO - 0008087      In-Store  WARE-MKL1006      26/9/20  30/12/20
# 7987  SO - 0008088        Online  WARE-NMK1003      26/9/20  30/12/20
# 7988  SO - 0008089        Online  WARE-UHY1004      26/9/20  30/12/20
# 7989  SO - 0008090        Online  WARE-NMK1003      26/9/20  30/12/20
# 7990  SO - 0008091      In-Store  WARE-UHY1004      26/9/20  30/12/20
#
#      ShipDate DeliveryDate CurrencyCode  _SalesTeamID  _CustomerID  _StoreID  \
# ...

# %%
df.head(20)
# Out:
#     OrderNumber Sales Channel WarehouseCode ProcuredDate OrderDate ShipDate  \
# 0   SO - 000101      In-Store  WARE-UHY1004     31/12/17   31/5/18  14/6/18
# 1   SO - 000102        Online  WARE-NMK1003     31/12/17   31/5/18  22/6/18
# 2   SO - 000103   Distributor  WARE-UHY1004     31/12/17   31/5/18  21/6/18
# 3   SO - 000104     Wholesale  WARE-NMK1003     31/12/17   31/5/18   2/6/18
# 4   SO - 000105   Distributor  WARE-NMK1003      10/4/18   31/5/18  16/6/18
# 5   SO - 000106        Online  WARE-PUJ1005     31/12/17   31/5/18   8/6/18
# 6   SO - 000107      In-Store  WARE-XYS1001     31/12/17   31/5/18   8/6/18
# 7   SO - 000108      In-Store  WARE-PUJ1005      10/4/18   31/5/18  26/6/18
# 8   SO - 000109      In-Store  WARE-PUJ1005     31/12/17    1/6/18  16/6/18
# 9   SO - 000110      In-Store  WARE-UHY1004     31/12/17    1/6/18  29/6/18
# 10  SO - 000111   Distributor  WARE-XYS1001     31/12/17    1/6/18  15/6/18
# ...

# %%
df.tail(20)
# Out:
#        OrderNumber Sales Channel WarehouseCode ProcuredDate OrderDate  \
# 7971  SO - 0008072     Wholesale  WARE-MKL1006      26/9/20  28/12/20
# 7972  SO - 0008073      In-Store  WARE-NMK1003      26/9/20  28/12/20
# 7973  SO - 0008074        Online  WARE-NMK1003      26/9/20  28/12/20
# 7974  SO - 0008075   Distributor  WARE-XYS1001      26/9/20  28/12/20
# 7975  SO - 0008076        Online  WARE-XYS1001      26/9/20  28/12/20
# 7976  SO - 0008077     Wholesale  WARE-NBV1002      26/9/20  28/12/20
# 7977  SO - 0008078        Online  WARE-PUJ1005      26/9/20  28/12/20
# 7978  SO - 0008079     Wholesale  WARE-PUJ1005      26/9/20  29/12/20
# 7979  SO - 0008080      In-Store  WARE-NBV1002      26/9/20  29/12/20
# 7980  SO - 0008081        Online  WARE-NMK1003      26/9/20  29/12/20
# 7981  SO - 0008082   Distributor  WARE-PUJ1005      26/9/20  29/12/20
# 7982  SO - 0008083      In-Store  WARE-NMK1003      26/9/20  29/12/20
# ...

# %%
df.shape
# Out:
# (7991, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderNumber       7991 non-null   object
#  1   Sales Channel     7991 non-null   object
#  2   WarehouseCode     7991 non-null   object
#  3   ProcuredDate      7991 non-null   object
#  4   OrderDate         7991 non-null   object
#  5   ShipDate          7991 non-null   object
#  6   DeliveryDate      7991 non-null   object
#  7   CurrencyCode      7991 non-null   object
#  8   _SalesTeamID      7991 non-null   int64
#  9   _CustomerID       7991 non-null   int64
#  10  _StoreID          7991 non-null   int64
#  11  _ProductID        7991 non-null   int64
#  12  Order Quantity    7991 non-null   int64
#  13  Discount Applied  7991 non-null   float64
#  14  Unit Cost         7991 non-null   object
#  15  Unit Price        7991 non-null   object
# ...

# %%
print(df['ShipDate'].head())
# Out:
# 0    14/6/18
# 1    22/6/18
# 2    21/6/18
# 3     2/6/18
# 4    16/6/18
# Name: ShipDate, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderNumber       7991 non-null   object
#  1   Sales Channel     7991 non-null   object
#  2   WarehouseCode     7991 non-null   object
#  3   ProcuredDate      7991 non-null   object
#  4   OrderDate         7991 non-null   object
#  5   ShipDate          7991 non-null   object
#  6   DeliveryDate      7991 non-null   object
#  7   CurrencyCode      7991 non-null   object
#  8   _SalesTeamID      7991 non-null   int64
#  9   _CustomerID       7991 non-null   int64
#  10  _StoreID          7991 non-null   int64
#  11  _ProductID        7991 non-null   int64
#  12  Order Quantity    7991 non-null   int64
#  13  Discount Applied  7991 non-null   float64
#  14  Unit Cost         7991 non-null   object
#  15  Unit Price        7991 non-null   object
# ...

# %%
df.head()
# Out:
#    OrderNumber Sales Channel WarehouseCode ProcuredDate OrderDate ShipDate  \
# 0  SO - 000101      In-Store  WARE-UHY1004     31/12/17   31/5/18  14/6/18
# 1  SO - 000102        Online  WARE-NMK1003     31/12/17   31/5/18  22/6/18
# 2  SO - 000103   Distributor  WARE-UHY1004     31/12/17   31/5/18  21/6/18
# 3  SO - 000104     Wholesale  WARE-NMK1003     31/12/17   31/5/18   2/6/18
# 4  SO - 000105   Distributor  WARE-NMK1003      10/4/18   31/5/18  16/6/18
#
#   DeliveryDate CurrencyCode  _SalesTeamID  _CustomerID  _StoreID  _ProductID  \
# 0      19/6/18          USD             6           15       259          12
# 1       2/7/18          USD            14           20       196          27
# 2       1/7/18          USD            21           16       213          16
# 3       7/6/18          USD            28           48       107          23
# 4      26/6/18          USD            22           49       111          26
#
# ...

# %%
df.describe()
# Out:
#        _SalesTeamID  _CustomerID     _StoreID   _ProductID  Order Quantity  \
# count   7991.000000  7991.000000  7991.000000  7991.000000     7991.000000
# mean      14.384307    25.457014   183.850081    23.771743        4.525341
# std        7.986086    14.414883   105.903946    13.526545        2.312631
# min        1.000000     1.000000     1.000000     1.000000        1.000000
# 25%        8.000000    13.000000    91.000000    12.000000        3.000000
# 50%       14.000000    25.000000   183.000000    24.000000        5.000000
# 75%       21.000000    38.000000   276.000000    36.000000        7.000000
# max       28.000000    50.000000   367.000000    47.000000        8.000000
#
#        Discount Applied
# count       7991.000000
# mean           0.114394
# std            0.085570
# min            0.050000
# 25%            0.050000
# 50%            0.075000
# 75%            0.150000
# max            0.400000

# %%
print(df['OrderDate'].dtype)
# Out:
# object

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
# Out:
# C:\Users\MICRO\AppData\Local\Temp\ipykernel_7072\3625972305.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# %%
df['OrderYear'] = df['OrderDate'].dt.year

# %%
df.OrderYear.nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# OrderNumber         0
# Sales Channel       0
# WarehouseCode       0
# ProcuredDate        0
# OrderDate           0
# ShipDate            0
# DeliveryDate        0
# CurrencyCode        0
# _SalesTeamID        0
# _CustomerID         0
# _StoreID            0
# _ProductID          0
# Order Quantity      0
# Discount Applied    0
# Unit Cost           0
# Unit Price          0
# OrderYear           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7986    False
# 7987    False
# 7988    False
# 7989    False
# 7990    False
# Length: 7991, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# OrderNumber         7991
# Sales Channel          4
# WarehouseCode          6
# ProcuredDate          11
# OrderDate            945
# ShipDate             966
# DeliveryDate         966
# CurrencyCode           1
# _SalesTeamID          28
# _CustomerID           50
# _StoreID             367
# _ProductID            47
# Order Quantity         8
# Discount Applied       7
# Unit Cost           5252
# Unit Price           664
# OrderYear              3
# dtype: int64

# %% [markdown]
# ## 1.Time Series Analysis-Sales trends over time to identify seasonal patterns and changes in demand

# %%
print(df.columns)
# Out:
# Index(['OrderNumber', 'Sales Channel', 'WarehouseCode', 'ProcuredDate',
#        'OrderDate', 'ShipDate', 'DeliveryDate', 'CurrencyCode', '_SalesTeamID',
#        '_CustomerID', '_StoreID', '_ProductID', 'Order Quantity',
#        'Discount Applied', 'Unit Cost', 'Unit Price', 'OrderYear'],
#       dtype='object')

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'], format='%d/%m/%y')

# %%
# Step 1: Remove commas (if any) and convert the column to float
df['Unit Price'] = df['Unit Price'].replace({',': ''}, regex=True).astype(float)

# Step 2: Convert the 'Unit Price' to integer (if you want the integer value)
df['Unit Price'] = df['Unit Price'].astype(int)

# If you want to create a 'Total' column based on 'Unit Price' and 'Order Quantity', 
# you can do it like this:
df['Total'] = df['Unit Price'] * df['Order Quantity']

print(df[['Unit Price', 'Total']])
# Out:
#       Unit Price  Total
# 0           1963   9815
# 1           3939  11817
# 2           1775   1775
# 3           2324  18592
# 4           1822  14576
# ...          ...    ...
# 7986         234    234
# 7987        3202  19212
# 7988        3825  19125
# 7989        1072   8576
# 7990        2211  11055
#
# [7991 rows x 2 columns]

# %%
df['Total'] = df['Unit Price'].astype(int)

# %%
df['Unit Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7991 entries, 0 to 7990
# Series name: Unit Price
# Non-Null Count  Dtype
# --------------  -----
# 7991 non-null   int32
# dtypes: int32(1)
# memory usage: 31.3 KB

# %%
df
# Out:
#        OrderNumber Sales Channel WarehouseCode ProcuredDate  OrderDate  \
# 0      SO - 000101      In-Store  WARE-UHY1004     31/12/17 2018-05-31
# 1      SO - 000102        Online  WARE-NMK1003     31/12/17 2018-05-31
# 2      SO - 000103   Distributor  WARE-UHY1004     31/12/17 2018-05-31
# 3      SO - 000104     Wholesale  WARE-NMK1003     31/12/17 2018-05-31
# 4      SO - 000105   Distributor  WARE-NMK1003      10/4/18 2018-05-31
# ...            ...           ...           ...          ...        ...
# 7986  SO - 0008087      In-Store  WARE-MKL1006      26/9/20 2020-12-30
# 7987  SO - 0008088        Online  WARE-NMK1003      26/9/20 2020-12-30
# 7988  SO - 0008089        Online  WARE-UHY1004      26/9/20 2020-12-30
# 7989  SO - 0008090        Online  WARE-NMK1003      26/9/20 2020-12-30
# 7990  SO - 0008091      In-Store  WARE-UHY1004      26/9/20 2020-12-30
#
#      ShipDate DeliveryDate CurrencyCode  _SalesTeamID  _CustomerID  _StoreID  \
# ...

# %%
df1=df

# %%
df1
# Out:
#        OrderNumber Sales Channel WarehouseCode ProcuredDate  OrderDate  \
# 0      SO - 000101      In-Store  WARE-UHY1004     31/12/17 2018-05-31
# 1      SO - 000102        Online  WARE-NMK1003     31/12/17 2018-05-31
# 2      SO - 000103   Distributor  WARE-UHY1004     31/12/17 2018-05-31
# 3      SO - 000104     Wholesale  WARE-NMK1003     31/12/17 2018-05-31
# 4      SO - 000105   Distributor  WARE-NMK1003      10/4/18 2018-05-31
# ...            ...           ...           ...          ...        ...
# 7986  SO - 0008087      In-Store  WARE-MKL1006      26/9/20 2020-12-30
# 7987  SO - 0008088        Online  WARE-NMK1003      26/9/20 2020-12-30
# 7988  SO - 0008089        Online  WARE-UHY1004      26/9/20 2020-12-30
# 7989  SO - 0008090        Online  WARE-NMK1003      26/9/20 2020-12-30
# 7990  SO - 0008091      In-Store  WARE-UHY1004      26/9/20 2020-12-30
#
#      ShipDate DeliveryDate CurrencyCode  _SalesTeamID  _CustomerID  _StoreID  \
# ...

# %%
df.to_csv(r"C:\Users\MICRO\Documents\anzz\New US_Regional_Sales_Data.csv",index=False)

# %%
sales_trend = pd.DataFrame(df.groupby('OrderYear')['Total'].sum()).reset_index()

# %%
sales_trend
# Out:
#    OrderYear    Total
# 0       2018  4182280
# 1       2019  6956586
# 2       2020  7113322

# %%
plt.figure(figsize=(14,8)) 
plt.plot(sales_trend['OrderYear'], sales_trend['Total'], marker='o', linestyle='-', color='b')
plt.title('Sales Trends Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)
plt.subplots_adjust(left=0.1, right=0.95, top=0.9, bottom=0.3)
plt.show()

# %% [markdown]
# **From the above graph we have found that if there is an upward slope, it indicates increasing sales over the years,if the trend is flat, sales have remained consistent,A downward slope would indicate a decline in sales.**

# %% [markdown]
# ## 2.Sales Channel Comparison - Compare sales performance across different channels

# %%
print(df.columns)
# Out:
# Index(['OrderNumber', 'Sales Channel', 'WarehouseCode', 'ProcuredDate',
#        'OrderDate', 'ShipDate', 'DeliveryDate', 'CurrencyCode', '_SalesTeamID',
#        '_CustomerID', '_StoreID', '_ProductID', 'Order Quantity',
#        'Discount Applied', 'Unit Cost', 'Unit Price', 'OrderYear', 'Total'],
#       dtype='object')

# %%
channel_performance = df.groupby('Sales Channel')['Total'].sum().reset_index()

# %%
channel_performance
# Out:
#   Sales Channel    Total
# 0   Distributor  3201147
# 1      In-Store  7485729
# 2        Online  5543763
# 3     Wholesale  2021549

# %%
plt.figure(figsize=(12,8))
plt.bar(channel_performance['Sales Channel'], channel_performance['Total'], color=['blue', 'green', 'orange'])
plt.title('Sales Performance Across Channels', fontsize=16)
plt.xlabel('Sales Channel', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()  
plt.show()

# %% [markdown]
# **From the above graph Sales Channels contribute the most to total sales, highlighting the dominant and underperforming channels. Dominant channels suggest where to focus resources, while weaker channels may require strategy adjustments to boost performance**

# %% [markdown]
# ## 3.Product Analysis - Visualise the distribution of sales across different products

# %%
print(df.columns)
# Out:
# Index(['OrderNumber', 'Sales Channel', 'WarehouseCode', 'ProcuredDate',
#        'OrderDate', 'ShipDate', 'DeliveryDate', 'CurrencyCode', '_SalesTeamID',
#        '_CustomerID', '_StoreID', '_ProductID', 'Order Quantity',
#        'Discount Applied', 'Unit Cost', 'Unit Price', 'OrderYear', 'Total'],
#       dtype='object')

# %%
product_sales = df.groupby('_ProductID')['Total'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(8, 8))
plt.pie(product_sales, labels=product_sales.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Sales Distribution Across Products')
plt.axis('equal')  
plt.show()

# %% [markdown]
# **From the above plot how sales are distributed across different products. It highlights which products contribute the most to total sales, and which ones have a smaller share.This visualization helps identify your top-performing products and shows the relative importance of each product in terms of sales.**

# %% [markdown]
# ## 4.Discount Analysis - Analyse the impact of discounts on sales

# %%
print(df.columns)
# Out:
# Index(['OrderNumber', 'Sales Channel', 'WarehouseCode', 'ProcuredDate',
#        'OrderDate', 'ShipDate', 'DeliveryDate', 'CurrencyCode', '_SalesTeamID',
#        '_CustomerID', '_StoreID', '_ProductID', 'Order Quantity',
#        'Discount Applied', 'Unit Cost', 'Unit Price', 'OrderYear', 'Total'],
#       dtype='object')

# %%
discount_analysis = df.groupby('Discount Applied')['Total'].mean().reset_index()

# %%
discount_analysis
# Out:
#    Discount Applied        Total
# 0             0.050  2286.257666
# 1             0.075  2308.873317
# 2             0.100  2215.536404
# 3             0.150  2243.892596
# 4             0.200  2284.956456
# 5             0.300  2370.143302
# 6             0.400  2422.433526

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.scatterplot(data=discount_analysis, x='Discount Applied', y='Total', alpha=0.7, color='blue')
plt.title('Impact of Discounts on Sales', fontsize=16)
plt.xlabel('Discount Applied (%)', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.show()

# %% [markdown]
# **From the above plot we can understand that the relationship between the percentage of discounts applied and the average total sales. It shows whether higher discounts lead to an increase or decrease in sales, helping identify the optimal discount range for maximizing revenue.**

# %% [markdown]
# ## 5. Regional Performance - Sales Performance Across Different Regions

# %%
print(df.columns)
# Out:
# Index(['OrderNumber', 'Sales Channel', 'WarehouseCode', 'ProcuredDate',
#        'OrderDate', 'ShipDate', 'DeliveryDate', 'CurrencyCode', '_SalesTeamID',
#        '_CustomerID', '_StoreID', '_ProductID', 'Order Quantity',
#        'Discount Applied', 'Unit Cost', 'Unit Price', 'OrderYear', 'Total'],
#       dtype='object')

# %%
region_sales = df.groupby('WarehouseCode')['Total'].sum().reset_index()

# %%
region_sales
# Out:
#   WarehouseCode    Total
# 0  WARE-MKL1006  1943411
# 1  WARE-NBV1002  1543927
# 2  WARE-NMK1003  5778345
# 3  WARE-PUJ1005  3257705
# 4  WARE-UHY1004  2947988
# 5  WARE-XYS1001  2780812

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.scatterplot(data=region_sales, x='WarehouseCode', y='Total', alpha=0.7, color='blue')
plt.title('Regional Performance ', fontsize=16)
plt.xlabel('WarehouseCode', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.show()

# %% [markdown]
# **From the above plot we can understand that the sales performance across different regions (represented by WarehouseCode). Each point shows the total sales for a specific warehouse, allowing for easy identification of regions with higher or lower sales. This visualization helps in assessing regional performance and can guide decisions on resource allocation, targeted marketing, or operational improvements in underperforming areas.**

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# ***By analysing the provided dataset on <span style="color: red;">US Regional Sales Data</span> we can clearly understand that multi-dimensional analysis provides actionable insights across time trends, sales channels, product contributions, discount strategies, and regional performance. By leveraging these findings, the business can make data-driven decisions to optimize revenue, improve operational efficiency, and refine strategic focus areas.***

# %%
df.to_csv(r"C:\Users\MICRO\Documents\anzz\Final Report Of US_Regional_Sales_Data.csv",index=False)
